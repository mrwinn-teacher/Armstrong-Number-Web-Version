# %% [markdown]
# <a href="https://colab.research.google.com/github/mrwinn-teacher/Armstrong-Number-Web-Version/blob/main/Armstrong_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import math

def is_armstrong_number(number):
    numlength = 1
    armstrongsum = 0
    calcnumb = number
    while calcnumb >= 10:
        numlength = numlength + 1
        calcnumb = calcnumb/10
    counter = numlength
    while counter > 0:
        armstrongsum = armstrongsum + math.trunc(calcnumb)**numlength
        calcnumb = round(calcnumb*10 - math.trunc(calcnumb)*10, numlength)
        counter = counter - 1
    if armstrongsum == number:
        return True
    return False

st.title("Armstrong Number Program")
number_string=" "
while not number_string.isdigit():
  number_string = st.text_input("Enter a number: ")
if is_armstrong_number(number):
    st.write(str(number) + " is an Armstrong number")
else:
    st.write(str(number) + " is not an Armstrong number")
# Out:
# 2026-09-11 16:39:44.428 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 16:39:44.651
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-09-11 16:39:44.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 16:39:44.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 16:39:44.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 16:39:44.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 16:39:44.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
